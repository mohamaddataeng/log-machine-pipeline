# %%
import pandas as pd

# %%
df = pd.read_csv("shipments.csv", parse_dates=["timestamp"])

# %%
df.head()
# Out:
#       shipment_id           timestamp severity           thread  \
# 0  Sp260318090056 2026-01-12 00:02:14     WARN  KickoutThread-1
# 1  Sp260318090057 2026-01-12 00:02:28     INFO    LabelThread-3
# 2  Sp260318090058 2026-01-12 00:02:42     WARN  KickoutThread-1
# 3  Sp260318090059 2026-01-12 00:02:55     WARN  KickoutThread-1
# 4  Sp260318090060 2026-01-12 00:03:09     INFO    LabelThread-4
#
#                                     source                event     station  \
# 0    com.logistic.conveyer.ScaleHandlerSys  Overweight detected  Station-04
# 1  com.logistic.labelmachine.SystemManager        Label printed  Station-06
# 2    com.logistic.conveyer.ScaleHandlerSys  Overweight detected  Station-07
# 3    com.logistic.conveyer.ScaleHandlerSys  Overweight detected  Station-05
# 4  com.logistic.labelmachine.SystemManager        Label printed  Station-02
#
#     box_barcode  articles  exp_weight_kg  ...  abs_weight_diff  \
# 0  BC_MEDIUM200       5.0          1.791  ...          0.06519
# 1    XX_LARGE60      18.0          4.247  ...          0.02591
# 2   BC_LARGE400       3.0          3.715  ...          0.19690
# 3    XX_LARGE80      20.0          3.986  ...          0.17778
# 4   BC_LARGE400       8.0          5.585  ...          0.05082
#
#    print_quality_pct  line_speed_mps       slam  iso_grade  \
# 0                NaN             NaN        NaN        NaN
# 1          100.00000            2.21  SLAM5_LP1          A
# 2                NaN             NaN        NaN        NaN
# 3                NaN             NaN        NaN        NaN
# 4           99.96875            1.87  SLAM5_LP2          A
#
#    pckg_problem_found weight_diff weight_diff_ratio distance_to_threshold  \
# 0                   N     0.06519             0.036              0.043698
# 1                 NaN    -0.02591             0.006             -0.025054
# 2                   N     0.19690             0.053              0.152320
# 3                   Y    -0.17778             0.045              0.129948
# 4                 NaN    -0.05082             0.009             -0.016200
#
#    is_kot
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5900 entries, 0 to 5899
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   shipment_id            5900 non-null   object
#  1   timestamp              5900 non-null   datetime64[ns]
#  2   severity               5900 non-null   object
#  3   thread                 5900 non-null   object
#  4   source                 5900 non-null   object
#  5   event                  5900 non-null   object
#  6   station                5760 non-null   object
#  7   box_barcode            5900 non-null   object
#  8   articles               5760 non-null   float64
#  9   exp_weight_kg          5760 non-null   float64
#  10  act_weight_kg          5760 non-null   float64
#  11  tare_weight_kg         5760 non-null   float64
#  12  product_weight_kg      5760 non-null   float64
#  13  abs_weight_diff        5760 non-null   float64
#  14  print_quality_pct      4456 non-null   float64
#  15  line_speed_mps         4456 non-null   float64
#  16  slam                   4456 non-null   object
#  17  iso_grade              4456 non-null   object
#  18  pckg_problem_found     1304 non-null   object
#  19  weight_diff            5760 non-null   float64
#  20  weight_diff_ratio      5760 non-null   float64
#  21  distance_to_threshold  5760 non-null   float64
#  22  is_kot                 5900 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#           articles  exp_weight_kg  act_weight_kg  tare_weight_kg  \
# count  5760.000000    5760.000000    5760.000000     5760.000000
# mean     10.649826       3.173276       3.316063        0.143410
# std       5.744195       1.622587       1.622862        0.074865
# min       1.000000       0.380000       0.450170        0.070000
# 25%       6.000000       1.788750       1.950610        0.090000
# 50%      11.000000       3.121000       3.270990        0.120000
# 75%      16.000000       4.590250       4.730252        0.240000
# max      20.000000       5.999000       6.485060        0.290000
#
#        product_weight_kg  abs_weight_diff  print_quality_pct  line_speed_mps  \
# count        5760.000000      5760.000000        4456.000000     4456.000000
# mean            3.172653         0.046323          94.066534        1.592338
# std             1.623382         0.059203           3.493632        0.460045
# min             0.376240         0.001370          88.012500        0.800000
# 25%             1.779930         0.013895          91.043750        1.210000
# 50%             3.127385         0.026160          94.081250        1.570000
# 75%             4.588150         0.048165          97.112500        1.980000
# max             6.305010         0.388360         100.000000        2.400000
#
#        weight_diff  weight_diff_ratio  distance_to_threshold       is_kot
# count  5760.000000        5760.000000            5760.000000  5900.000000
# mean      0.000623           0.014476               0.008244     0.221017
# std       0.075172           0.015028               0.054266     0.414967
# min      -0.358010           0.003000              -0.052844     0.000000
# 25%      -0.026343           0.006000              -0.017162     0.000000
# 50%      -0.002295           0.009000              -0.007018     0.000000
# 75%       0.025960           0.012000              -0.000645     0.000000
# max       0.388360           0.065000               0.316552     1.000000

# %% [markdown]
# ## **Analyse: Einfluss der Schichtzeiten auf Maschinenleistung**
#
# Gibt es Auffälligkeiten zwischen den Schichten (Früh, Spät, Nacht), die einen Einfluss auf die Maschinenleistung und Produktivität haben?
#
# Dabei wird untersucht, ob sich die Fehlerquote (Kickout-Rate) und die Produktivität zwischen den Schichten unterscheiden.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ==============================
# 1. Vorbereitung
# ==============================

df = df.copy()

df["timestamp"] = pd.to_datetime(df["timestamp"])
df["hour"] = df["timestamp"].dt.hour

# %%
# 2. Schichten definieren
# ==============================
df["hour"] = df["timestamp"].dt.hour
conditions = [
    (df["hour"]>=22) |  (df["hour"]<6),
    (df["hour"]>=6)  & (df["hour"]<14),
    (df["hour"]>=14) & (df["hour"]<22)
]
choices = [
    "Nachschicht",
    "Frühschicht",
    "Spätschicht"
]
df["shift"] = np.select(conditions, choices, default="unbekannt")

# %%
# ==============================
# 3. KPI-Tabelle pro Schicht
# ==============================

shift_kpis = df.groupby("shift").agg(
    total_shipments=("shipment_id", "count"),
    kickouts=("is_kot", "sum"),
    kickout_rate=("is_kot", "mean"),
    avg_speed=("line_speed_mps", "mean")
).reset_index()

shift_kpis = shift_kpis.sort_values(by="kickout_rate", ascending=False)

print(shift_kpis)
# Out:
#          shift  total_shipments  kickouts  kickout_rate  avg_speed
# 1  Nachschicht             2043       467      0.228585   1.599810
# 2  Spätschicht             1746       379      0.217068   1.591885
# 0  Frühschicht             2111       458      0.216959   1.585589

# %%
# ==============================
# 4. Plot
# ==============================

sns.set_style("white")
sns.set_context("talk")

plt.figure(figsize=(8, 5))

ax = sns.barplot(
    data=shift_kpis,
    x="shift",
    y="kickout_rate",
    hue="shift",
    palette="Blues_r",
    legend=False
)

plt.title("Kickout-Rate pro Schicht", fontsize=16, weight="bold")
plt.xlabel("Schicht", fontsize=12)
plt.ylabel("Kickout-Rate", fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

for i, v in enumerate(shift_kpis["kickout_rate"]):
    ax.text(i, v + 0.003, f"{v:.2f}", ha="center", fontsize=10)

plt.tight_layout()
plt.show()

# %%
# ==============================
# 5. KPI Summary (für Dashboard)
# ==============================

avg_kickout = shift_kpis["kickout_rate"].mean()
worst_shift = shift_kpis.iloc[0]["shift"]
best_shift = shift_kpis.iloc[-1]["shift"]

print("\n===== KPI SUMMARY =====")
print(f"Durchschnittliche Kickout-Rate: {avg_kickout:.3f}")
print(f"Schlechteste Schicht: {worst_shift}")
print(f"Beste Schicht: {best_shift}")
# Out:
# ===== KPI SUMMARY =====
# Durchschnittliche Kickout-Rate: 0.221
# Schlechteste Schicht: Nachschicht
# Beste Schicht: Frühschicht

# %% [markdown]
# ## **Fazit: Schichtvergleich**
#
# Die Analyse zeigt keine signifikanten Unterschiede in der Kickout-Rate zwischen den einzelnen Schichten (Früh-, Spät- und Nachtschicht).
#
# Die Fehlerquote bleibt über alle Schichten hinweg auf einem vergleichbaren Niveau, sodass kein klarer Einfluss der Schichtzugehörigkeit auf die Maschinenleistung festgestellt werden kann.
#
# Auch hinsichtlich der Produktivität ergeben sich keine auffälligen Abweichungen.
#
# **Ergebnis:**
# - Keine auffällige Schicht identifiziert
# - Maschinenleistung ist schichtunabhängig stabil
# - Kein Handlungsbedarf auf Schichtebene

# %% [markdown]
# ## **Analyse: Einfluss der Schichtwechselzeiten auf Maschinenleistung**
#
# Gibt es Auffälligkeiten rund um die Schichtwechselzeitpunkte (06:00, 14:00, 22:00 Uhr), die einen Einfluss auf die Maschinenleistung und Produktivität haben?
#
# Dabei wird untersucht, ob es unmittelbar vor, während oder nach den Schichtwechseln zu Veränderungen in der Fehlerquote (Kickout-Rate), der Druckqualität oder der Verarbeitungsgeschwindigkeit kommt.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# KPI berechnen
kickout_rate = df.groupby("hour")["is_kot"].mean().reset_index()

# Style
sns.set_style("white")
sns.set_context("talk")

plt.figure(figsize=(12, 5))

ax = sns.lineplot(
    data=kickout_rate,
    x="hour",
    y="is_kot",
    marker="o"
)

# Schichtwechsel markieren
for h in [6, 14, 22]:
    plt.axvline(x=h, linestyle="--", color="red", alpha=0.6)
    
# Global mean line
mean_val = df["is_kot"].mean()
plt.axhline(mean_val, linestyle=":", color="black", alpha=0.7)

plt.title("Kickout-Rate rund um Schichtwechselzeiten", fontsize=16, weight="bold")
plt.xlabel("Uhrzeit", fontsize=12)
plt.ylabel("Kickout-Rate", fontsize=12)

plt.xticks(range(0, 24), fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Fazit: Schichtwechsel-Zeitpunkte**
#
# Die Analyse der Kickout-Rate über den Tagesverlauf zeigt auffällige Veränderungen rund um einzelne Schichtwechsel-Zeitpunkte.
#
# Insbesondere treten bei **06:00 Uhr** und **22:00 Uhr** deutliche Peaks in der Kickout-Rate auf, die über dem durchschnittlichen Niveau liegen. Der Schichtwechsel um **14:00 Uhr** zeigt hingegen keine vergleichbare Auffälligkeit.
#
# Dies deutet darauf hin, dass nicht alle Schichtwechsel gleichermaßen kritisch sind, jedoch insbesondere die Übergänge um **06:00 Uhr** und **22:00 Uhr** mit einer erhöhten Fehlerquote verbunden sein könnten.
#
# **Ergebnis:**
# - Auffällige Peaks bei **06:00 Uhr** und **22:00 Uhr**
# - Kein klarer Peak bei **14:00 Uhr**
# - Hinweise auf mögliche Übergabe- oder Prozessprobleme bei einzelnen Schichtwechseln

# %% [markdown]
# ## **Dashboard: Schichtwechsel-Zeitpunkte**
#
# ### **Hauptvisualisierung**
# - Linienplot: Kickout-Rate über den Tagesverlauf
# - Markierungen bei Schichtwechseln: 06:00, 14:00, 22:00
#
# ### **KPIs**
# - Durchschnittliche Kickout-Rate: ~22%
# - Auffällige Zeitpunkte: 06:00, 22:00
# - Unauffälliger Schichtwechsel: 14:00
#
# ### **Insight**
# Erhöhte Fehlerquoten treten insbesondere bei den Schichtwechseln um 06:00 und 22:00 Uhr auf.
# Dies deutet auf mögliche Übergabeprobleme oder Prozessinstabilitäten zu diesen Zeitpunkten hin.
#
# ## **Handlungsempfehlung: Schichtwechselzeiten**
#
# - Übergabeprozesse zwischen Schichten standardisieren (Checklisten, feste Abläufe)
# - Maschinenstatus vor Schichtwechsel aktiv prüfen (Kalibrierung, Druckqualität)
# - Kurzzeitige Qualitätskontrolle nach Schichtstart einführen
# - Schulung der Mitarbeiter für saubere Übergaben und Maschinenhandling

# %%
import pandas as pd

# %%
df = pd.read_csv("Events.csv")

# %%
display(df.head())
# Out:
#       shipment_id            timestamp severity  \
# 0  Sp260312074341  2026-01-12 00:02:13     INFO
# 1  Sp260312074342  2026-01-12 00:02:27     INFO
# 2  Sp260312074343  2026-01-12 00:02:42     INFO
# 3  Sp260312074344  2026-01-12 00:02:55     WARN
# 4  Sp260312074345  2026-01-12 00:03:09     WARN
#
#                                       thread   thread_label  \
# 0  ['LabelThread-2' 'VerifyThread-1' 'main']  LabelThread-2
# 1  ['LabelThread-4' 'VerifyThread-2' 'main']  LabelThread-4
# 2  ['LabelThread-3' 'VerifyThread-3' 'main']  LabelThread-3
# 3                        ['KickoutThread-1']            NaN
# 4                        ['KickoutThread-1']            NaN
#
#                                         source  \
# 0  ['com.logistic.labelmachine.SystemManager']
# 1  ['com.logistic.labelmachine.SystemManager']
# 2  ['com.logistic.labelmachine.SystemManager']
# 3    ['com.logistic.conveyer.ScaleHandlerSys']
# 4    ['com.logistic.conveyer.ScaleHandlerSys']
#
#                                          log_message  \
# 0  Label printed | SHIPMENT_ID=Sp260312074341 | S...
# 1  Label printed | SHIPMENT_ID=Sp260312074342 | S...
# 2  Label printed | SHIPMENT_ID=Sp260312074343 | S...
# 3  Overweight detected | SHIPMENT_ID=Sp2603120743...
# 4  Overweight detected | SHIPMENT_ID=Sp2603120743...
#
#                                                event     station  \
# 0  ['Label printed' 'Verification successful'\n '...  Station-03
# 1  ['Label printed' 'Verification successful'\n '...  Station-08
# 2  ['Label printed' 'Verification successful'\n '...  Station-08
# 3                            ['Overweight detected']  Station-10
# 4                            ['Overweight detected']  Station-02
#
#     box_barcode  ...  print_quality_pct  line_speed_mps       slam  iso_grade  \
# 0    XX_LARGE80  ...          100.00000            1.55  SLAM5_LP1          A
# 1    RK_SMALL90  ...           99.96875            0.82  SLAM5_LP2          A
# 2  BC_MEDIUM200  ...           99.91250            2.13  SLAM5_LP1          A
# 3  BC_MEDIUM200  ...                NaN             NaN        NaN        NaN
# 4  BC_MEDIUM200  ...                NaN             NaN        NaN        NaN
#
#    pckg_problem_found  weight_diff  weight_diff_ratio  distance_to_threshold  \
# 0                 NaN     -0.01642              0.006              -0.015872
# 1                 NaN     -0.02854              0.008              -0.013220
# 2                 NaN     -0.02459              0.004              -0.045670
# 3                   N      0.03083              0.030               0.018662
# 4                   N      0.04927              0.063               0.039886
#
#    is_kot  is_kot_regel
# 0       0             0
# 1       0             0
# 2       0             0
# 3       1             1
# 4       1             1
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (5893, 28)

# %%
df.columns
# Out:
# Index(['shipment_id', 'timestamp', 'severity', 'thread', 'thread_label',
#        'source', 'log_message', 'event', 'station', 'box_barcode', 'articles',
#        'exp_weight_kg', 'act_weight_kg', 'tare_weight_kg', 'product_weight_kg',
#        'abs_weight_diff', 'kot_pct', 'limit_kg', 'print_quality_pct',
#        'line_speed_mps', 'slam', 'iso_grade', 'pckg_problem_found',
#        'weight_diff', 'weight_diff_ratio', 'distance_to_threshold', 'is_kot',
#        'is_kot_regel'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5893 entries, 0 to 5892
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   shipment_id            5893 non-null   object
#  1   timestamp              5893 non-null   object
#  2   severity               5893 non-null   object
#  3   thread                 5893 non-null   object
#  4   source                 5893 non-null   object
#  5   log_message            5893 non-null   object
#  6   event                  5893 non-null   object
#  7   station                5773 non-null   object
#  8   box_barcode            5893 non-null   object
#  9   articles               4601 non-null   float64
#  10  exp_weight_kg          5773 non-null   float64
#  11  act_weight_kg          5773 non-null   float64
#  12  tare_weight_kg         5773 non-null   float64
#  13  product_weight_kg      5773 non-null   float64
#  14  abs_weight_diff        5773 non-null   float64
#  15  kot_pct                5773 non-null   float64
#  16  limit_kg               1172 non-null   float64
#  17  print_quality_pct      4601 non-null   float64
#  18  line_speed_mps         4601 non-null   float64
#  19  slam                   4601 non-null   object
#  20  iso_grade              4601 non-null   object
#  21  pckg_problem_found     1172 non-null   object
#  22  weight_diff            5773 non-null   float64
#  23  weight_diff_ratio      5773 non-null   float64
#  24  distance_to_threshold  5773 non-null   float64
#  25  is_kot                 5893 non-null   int64
#  26  is_kot_regel           5893 non-null   int64
# dtypes: float64(13), int64(2), object(12)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#           articles  exp_weight_kg  act_weight_kg  tare_weight_kg  \
# count  4601.000000    5773.000000    5773.000000     5773.000000
# mean     10.462943       3.218667       3.361045        0.142908
# std       5.792535       1.617791       1.622610        0.073985
# min       1.000000       0.380000       0.467160        0.070000
# 25%       6.000000       1.811000       1.964790        0.090000
# 50%      10.000000       3.227000       3.366420        0.120000
# 75%      15.000000       4.626000       4.761100        0.240000
# max      20.000000       5.999000       6.583110        0.290000
#
#        product_weight_kg  abs_weight_diff       kot_pct      limit_kg  \
# count        5773.000000      5773.000000  5.773000e+03  1.172000e+03
# mean            3.218137         0.043546  1.200000e+00  5.900000e+00
# std             1.619510         0.055144  1.185821e-13  1.101811e-13
# min             0.377570         0.001520  1.200000e+00  5.900000e+00
# 25%             1.809180         0.013660  1.200000e+00  5.900000e+00
# 50%             3.215450         0.025700  1.200000e+00  5.900000e+00
# 75%             4.619780         0.046200  1.200000e+00  5.900000e+00
# max             6.311000         0.369000  1.200000e+00  5.900000e+00
#
#        print_quality_pct  line_speed_mps  weight_diff  weight_diff_ratio  \
# count        4601.000000      4601.00000  5773.000000        5773.000000
# mean           94.077239         1.58401     0.000530           0.013594
# std             3.453977         0.46213     0.070265           0.014327
# min            88.012500         0.80000    -0.369000           0.003000
# 25%            91.131250         1.18000    -0.025900           0.006000
# 50%            94.106250         1.57000     0.003200           0.008000
# 75%            97.056250         1.98000     0.025590           0.011000
# max           100.000000         2.40000     0.357010           0.065000
#
#        distance_to_threshold       is_kot  is_kot_regel
# count            5773.000000  5893.000000   5893.000000
# mean                0.004922     0.198880      0.185644
# std                 0.050881     0.399191      0.388852
# min                -0.052710     0.000000      0.000000
# 25%                -0.019362     0.000000      0.000000
# 50%                -0.008058     0.000000      0.000000
# 75%                -0.001116     0.000000      0.000000
# max                 0.300064     1.000000      1.000000

# %%
# Kickout-Pakete vs normale Pakete
print(df["is_kot"].value_counts())
# Out:
# is_kot
# 0    4721
# 1    1172
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["timestamp"] = pd.to_datetime(df["timestamp"])
df["hour"] = df["timestamp"].dt.hour
kickout_rate = df.groupby("hour")["is_kot"].mean()
plt.figure()
plt.plot(kickout_rate.index, kickout_rate.values)

plt.xlabel("Zeit")
plt.ylabel("Kickout-Rate")
plt.title("Kickouts über Zeit")

plt.show()

# %%
# Unterscheiden sich Gewichtsabweichungen zwischen Kickout-Paketen und normalen Pakete?
df.groupby("is_kot")["abs_weight_diff"].mean()
# Out:
# is_kot
# 0    0.023783
# 1    0.121128
# Name: abs_weight_diff, dtype: float64

# %%
# Kickout-Rate abhängig von der Sation?
df.groupby(["station"])["is_kot"].mean()
# Out:
# station
# Station-01    0.170683
# Station-02    0.202756
# Station-03    0.247967
# Station-04    0.184211
# Station-05    0.196356
# Station-06    0.200000
# Station-07    0.215768
# Station-08    0.171429
# Station-09    0.183673
# Station-10    0.193396
# Station-11    0.233405
# Station-12    0.235294
# Name: is_kot, dtype: float64

# %%
# Unterscheidet sich die Verteilung von weight_diff, weight_diff_ratio oder act_weight_kg zwischen Kickout und normalen Paketen?
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="is_kot", y="weight_diff_ratio", data=df)

plt.title("Verteilung von weight_diff_ratio zwischen Kickout & normale Pakete")
plt.show()

# %%
# Gibt es Auffälligkeiten innerhalb der Schichtwechselzeiten (06:00, 14:00, 22:00)
df["timestamp"] = pd.to_datetime(df["timestamp"])
df["hour"] = df["timestamp"].dt.hour

# Kickout-Rate pro Stunde
df.groupby("hour")["is_kot"].mean().sort_index()
# Out:
# hour
# 0     0.207031
# 1     0.205993
# 2     0.182836
# 3     0.191011
# 4     0.180451
# 5     0.203008
# 6     0.290984
# 7     0.221805
# 8     0.176030
# 9     0.187266
# 10    0.214286
# 11    0.213483
# 12    0.253731
# 13    0.173585
# 14    0.172131
# 15    0.206767
# 16    0.199029
# 17    0.200000
# 18    0.201970
# 19    0.174757
# 20    0.209756
# 21    0.131707
# 22    0.155080
# 23    0.195489
# Name: is_kot, dtype: float64

# %%
df.groupby("hour")["is_kot"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='hour'>

# %%
#Der höchste Wert tritt um 06:00 Uhr auf. In dieser Stunde beträgt die Kickout-Rate ungefähr 29 %, was deutlich über dem durchschnittlichen Wert von etwa 20 % liegt. 
#Dieser Peak fällt zeitlich mit dem Beginn der Frühschicht zusammen. Eine mögliche Erklärung hierfür sind Prozesse rund um den Schichtwechsel, 
#wie beispielsweise Maschinenstart, Kalibrierung der Sensorik oder eine Umstellung der Bedienung durch neue Operatoren.
#Ein weiterer erhöhter Wert zeigt sich um 12:00 Uhr, wo die Kickout-Rate etwa 25 % beträgt. Dies könnte auf ein erhöhtes Paketvolumen während der Mittagszeit zurückzuführen sein,
#wodurch die Anlage unter höherer Last arbeitet und Fehler wahrscheinlicher werden.
# Out:
# slam
# SLAM5_LP1    0.0
# SLAM5_LP2    0.0
# Name: is_kot, dtype: float64

# %%
df.groupby("slam")["is_kot"].mean().sort_index()
# Out:
# slam
# SLAM5_LP1    0.0
# SLAM5_LP2    0.0
# Name: is_kot, dtype: float64

# %%
# Stunden 5 bis 7 filtern
df_shift = df[df["hour"].between(5,7)]

# Kickout-Rate pro Stunde in diesem Bereich
df_shift.groupby("hour")["is_kot"].mean()
# Out:
# hour
# 5    0.203008
# 6    0.290984
# 7    0.221805
# Name: is_kot, dtype: float64

# %%
df_shift.groupby("hour")["is_kot"].agg(["count","mean"])
# Out:
#       count      mean
# hour
# 5       266  0.203008
# 6       244  0.290984
# 7       266  0.221805

# %%
# nur normale Pakete
df_normal = df[df["is_kot"] == 0]

# Statistik der ratio
df_normal["weight_diff_ratio"].describe()
# Out:
# count    4601.000000
# mean        0.007377
# std         0.002622
# min         0.003000
# 25%         0.005000
# 50%         0.007000
# 75%         0.010000
# max         0.012000
# Name: weight_diff_ratio, dtype: float64

# %%
df_normal[df_normal["weight_diff_ratio"] > 0.010]["weight_diff_ratio"].count()
# Out:
# 700

# %%
df_kot = df[df["is_kot"] == 1]
df_kot["weight_diff_ratio"].describe()
# Out:
# count    1172.000000
# mean        0.038002
# std         0.015383
# min         0.012000
# 25%         0.024750
# 50%         0.038000
# 75%         0.052000
# max         0.065000
# Name: weight_diff_ratio, dtype: float64

# %%
df_kot[df_kot["weight_diff_ratio"] < 0.015]["weight_diff_ratio"].count()
# Out:
# 69

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=df, x="abs_weight_diff")
plt.show()

# %%
sns.displot(data=df, x="abs_weight_diff", col="is_kot")

# %%
sns.displot(data=df, x="weight_diff_ratio", col="is_kot")

# %%
sns.displot(data = df, x = "product_weight_kg", col = "is_kot")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    data=df,
    x="product_weight_kg",
    y="abs_weight_diff",
    hue="is_kot"
)

plt.xlabel("product_weight_kg")
plt.ylabel("abs_weight_diff")
plt.title("Scatterplot: Product Weight vs Absolute Weight Difference")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    data=df,
    x="exp_weight_kg",
    y="abs_weight_diff",
    hue="is_kot"
)

plt.xlabel("exp_weight_kg")
plt.ylabel("abs_weight_diff")
plt.title("Scatterplot: exp_weight_kg vs Absolute Weight Difference")

plt.show()

# %%
df[["product_weight_kg", "exp_weight_kg"]].corr()
# Out:
#                    product_weight_kg  exp_weight_kg
# product_weight_kg           1.000000       0.999058
# exp_weight_kg               0.999058       1.000000

# %%
df_kickout = df[df["is_kot"] == 1]

# %%
df_kickout
# Out:
#          shipment_id            timestamp severity               thread  \
# 3     Sp260312074344  2026-01-12 00:02:55     WARN  ['KickoutThread-1']
# 4     Sp260312074345  2026-01-12 00:03:09     WARN  ['KickoutThread-1']
# 7     Sp260312074348  2026-01-12 00:03:50     WARN  ['KickoutThread-1']
# 9     Sp260312074350  2026-01-12 00:04:16     WARN  ['KickoutThread-1']
# 13    Sp260312074354  2026-01-12 00:05:09     WARN  ['KickoutThread-1']
# ...              ...                  ...      ...                  ...
# 5870  Sp260312080211  2026-01-12 23:54:11     WARN  ['KickoutThread-1']
# 5873  Sp260312080214  2026-01-12 23:54:52     WARN  ['KickoutThread-1']
# 5875  Sp260312080216  2026-01-12 23:55:19     WARN  ['KickoutThread-1']
# 5886  Sp260312080227  2026-01-12 23:57:42     WARN  ['KickoutThread-1']
# 5890  Sp260312080231  2026-01-12 23:58:36     WARN  ['KickoutThread-1']
#
#      thread_label                                     source  \
# 3             NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 4             NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 7             NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 9             NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 13            NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# ...           ...                                        ...
# 5870          NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 5873          NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 5875          NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 5886          NaN  ['com.logistic.conveyer.ScaleHandlerSys']
# 5890          NaN  ['com.logistic.conveyer.ScaleHandlerSys']
#
#                                             log_message  \
# 3     Overweight detected | SHIPMENT_ID=Sp2603120743...
# 4     Overweight detected | SHIPMENT_ID=Sp2603120743...
# 7     Overweight detected | SHIPMENT_ID=Sp2603120743...
# 9     Overweight detected | SHIPMENT_ID=Sp2603120743...
# 13    Overweight detected | SHIPMENT_ID=Sp2603120743...
# ...                                                 ...
# 5870  Overweight detected | SHIPMENT_ID=Sp2603120802...
# 5873  Overweight detected | SHIPMENT_ID=Sp2603120802...
# 5875  Overweight detected | SHIPMENT_ID=Sp2603120802...
# 5886  Overweight detected | SHIPMENT_ID=Sp2603120802...
# 5890  Overweight detected | SHIPMENT_ID=Sp2603120802...
#
#                         event     station   box_barcode  ...  \
# 3     ['Overweight detected']  Station-10  BC_MEDIUM200  ...
# 4     ['Overweight detected']  Station-02  BC_MEDIUM200  ...
# 7     ['Overweight detected']  Station-06   BC_LARGE400  ...
# 9     ['Overweight detected']  Station-01    RK_SMALL60  ...
# 13    ['Overweight detected']  Station-02  BC_MEDIUM200  ...
# ...                       ...         ...           ...  ...
# 5870  ['Overweight detected']  Station-03    XX_LARGE60  ...
# 5873  ['Overweight detected']  Station-06    XX_LARGE80  ...
# 5875  ['Overweight detected']  Station-01    XX_LARGE60  ...
# 5886  ['Overweight detected']  Station-07    RK_SMALL90  ...
# 5890  ['Overweight detected']  Station-11    RK_SMALL60  ...
#
#       print_quality_pct  line_speed_mps  slam  iso_grade  pckg_problem_found  \
# 3                   NaN             NaN   NaN        NaN                   N
# 4                   NaN             NaN   NaN        NaN                   N
# 7                   NaN             NaN   NaN        NaN                   N
# 9                   NaN             NaN   NaN        NaN                   N
# 13                  NaN             NaN   NaN        NaN                   N
# ...                 ...             ...   ...        ...                 ...
# 5870                NaN             NaN   NaN        NaN                   N
# 5873                NaN             NaN   NaN        NaN                   N
# 5875                NaN             NaN   NaN        NaN                   N
# 5886                NaN             NaN   NaN        NaN                   N
# 5890                NaN             NaN   NaN        NaN                   N
#
#       weight_diff  weight_diff_ratio  distance_to_threshold  is_kot  \
# 3         0.03083              0.030               0.018662       1
# 4         0.04927              0.063               0.039886       1
# 7        -0.08002              0.052               0.061624       1
# 9         0.06923              0.032               0.043106       1
# 13       -0.22837              0.041               0.161854       1
# ...           ...                ...                    ...     ...
# 5870     -0.14439              0.057               0.113886       1
# 5873      0.11221              0.023               0.052366       1
# 5875     -0.31618              0.056               0.248428       1
# 5886      0.01675              0.015               0.003442       1
# 5890     -0.03871              0.012               0.000946       1
#
#       is_kot_regel
# 3                1
# 4                1
# 7                1
# 9                1
# 13               1
# ...            ...
# 5870             1
# 5873             1
# 5875             1
# 5886             1
# 5890             0
#
# [1172 rows x 28 columns]

# %%
# wie weit der Wert von der erlaubten Grenze entfernt ist.
# distance_to_threshold =abs_weight_diff − (exp_weight_kg × 0.012)
import seaborn as sns 
sns.displot(data = df_kickout, x = "distance_to_threshold", col = "is_kot")

# %%
df_kickout["distance_to_threshold"].describe()
# Out:
# count    1.172000e+03
# mean     8.264603e-02
# std      6.795769e-02
# min     -6.175616e-16
# 25%      2.649100e-02
# 50%      6.401900e-02
# 75%      1.256655e-01
# max      3.000640e-01
# Name: distance_to_threshold, dtype: float64

# %%
bins = [0, 0.005, 0.01, 0.02, 0.05, float("inf")]
df_kickout = df_kickout.copy()
df_kickout["distance_bin"] = pd.cut(
    df_kickout["distance_to_threshold"],
    bins=bins
)

# %%
# Bins definieren
bins = [0, 0.005, 0.01, 0.015, 0.02, 0.05, 0.1]

df["ratio_bin"] = pd.cut(df["weight_diff_ratio"], bins=bins)

# Kickout-Rate pro Bin
df.groupby("ratio_bin", observed=True)["is_kot"].agg(["count","mean"])
# Out:
#                count      mean
# ratio_bin
# (0.0, 0.005]    1336  0.000000
# (0.005, 0.01]   2565  0.000000
# (0.01, 0.015]    790  0.113924
# (0.015, 0.02]    111  1.000000
# (0.02, 0.05]     658  1.000000
# (0.05, 0.1]      313  1.000000

# %%
df_kickout.columns

# %%
counts = df_kickout["distance_bin"].value_counts()

# %%
counts/1172 * 100
# Out:
# distance_bin
# (0.05, inf]      57.764505
# (0.02, 0.05]     23.805461
# (0.01, 0.02]      8.617747
# (0.0, 0.005]      4.863481
# (0.005, 0.01]     4.692833
# Name: count, dtype: float64

# %%
#Kickout-Rate pro Drucker:
df.groupby("thread_label")["is_kot"].mean()
# Out:
# thread_label
# LabelThread-1    0.0
# LabelThread-2    0.0
# LabelThread-3    0.0
# LabelThread-4    0.0
# Name: is_kot, dtype: float64
